# %% [markdown]
# # Applied Questions _ Chapter_8

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import Ridge,Lasso,LogisticRegression
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor
from sklearn.metrics import mean_squared_error,accuracy_score,confusion_matrix
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn import tree
from xgboost import XGBRegressor,XGBClassifier
from sklearn.neighbors import KNeighborsClassifier


from tqdm import tqdm
import graphviz
from IPython.display import HTML

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 7. In the lab, we applied random forests to the Boston data using mtry=6 and using ntree=25 and ntree=500. Create a plot displaying the test error resulting from random forests on this data set for a more comprehensive range of values for mtry and ntree. You can model your plot after Figure 8.10. Describe the results obtained

# %%
boston_data = load_boston()
boston = pd.DataFrame(boston_data['data'],columns=boston_data['feature_names'])
boston['MEDV'] = boston_data['target']
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Before going any further, i consider a good practice to go through the data once, and see what the columns describe.

# %% [markdown]
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per $10,000
#
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's

# %%
#splitting the data into train and test 
X_train,X_test,y_train,y_test = train_test_split(boston.drop('MEDV',axis=1),boston['MEDV'],test_size = 0.5,)

# %%
p = boston.drop('MEDV',axis = 1).shape[1] # total number of features
max_features_dict = {'p':p,'p/2':int(p/2),'sqrt(p)':int(np.sqrt(p))} # or we can also use keywords like 'auto','sqrt'
scores_dict = {}

# %% [markdown]
# randomforestregressor - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html
# We would be focussing on two paramters - n_estimators and max_features

# %%
from tqdm import tqdm
scores_dict = {}
for max_feature_value in ['p','p/2','sqrt(p)']:
    max_feat = max_features_dict[max_feature_value]
    scores = []
    for n_estimator in tqdm(range(1,501,10)):
        rf = RandomForestRegressor(n_estimators=n_estimator,max_features=max_feat)
        rf.fit(X_train,y_train)
        scores.append(mean_squared_error(y_test,rf.predict(X_test)))
    scores_dict[max_feature_value] = scores

# %%
scores_dict.keys()

# %%
df = pd.DataFrame(scores_dict)
df.index = np.arange(1,501,10)

# %%
df.plot(figsize = (10,6))
plt.ylim(10,25)
plt.xlabel('Number of Trees')
plt.ylabel('Test MSE')
# Out:
# Text(0, 0.5, 'Test MSE')

# %% [markdown]
# ## 8. In the lab, a classification tree was applied to the Carseats data set after converting Sales into a qualitative response variable. Now we will seek to predict Sales using regression trees and related approaches, treating the response as a quantitative variable

# %%
carseats = pd.read_csv('E:\programming\dataset\Into_to_statstical_learning\Carseats.csv')
print(carseats.shape)
carseats.head()
# Out:
# (400, 11)
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %% [markdown]
# ( Optional )
# Going through the data columns -
# - Sales: unit sales in thousands
# - CompPrice: price charged by competitor at each location
# - Income: community income level in 1000s of dollars
# - Advertising: local ad budget at each location in 1000s of dollars
# - Population: regional pop in thousands
# - Price: price for car seats at each site
# - ShelveLoc: Bad, Good or Medium indicates quality of shelving location
# - Age: age level of the population
# - Education: ed level at location
# - Urban: Yes/No
# - US: Yes/No

# %%
data = carseats.copy()
# as the labels are ordinal, we would only be using label encoder, and since the values are small in number, we will map them
yes_no_dict = {'Yes':1,'No':0}
data['Urban'] = data['Urban'].map(yes_no_dict)
data['US'] = data['US'].map(yes_no_dict)
data['ShelveLoc'] = data['ShelveLoc'].map({'Bad':0,'Good':1,'Medium':3})

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          3   59
# 3   7.40        117     100            4         466     97          3   55
# 4   4.15        141      64            3         340    128          0   38
#
#    Education  Urban  US
# 0         17      1   1
# 1         10      1   1
# 2         12      1   1
# 3         14      1   1
# 4         13      1   0

# %% [markdown]
# ### (a) Split the data set into a training set and a test set.

# %%
X_train,X_test,y_train,y_test = train_test_split(data.drop('Sales',axis= 1),data['Sales'],test_size = 0.5,random_state = 1)
print(X_train.shape,X_test.shape)
# Out:
# (200, 10) (200, 10)

# %% [markdown]
# ### (b) Fit a regression tree to the training set. Plot the tree, and interpret the results. What test MSE do you obtain?

# %%
model = DecisionTreeRegressor()
model.fit(X_train,y_train)
print('Training MSE is ',mean_squared_error(y_train,model.predict(X_train))) 
## what the hell, its surely overfitting, lets now plot the tree and caclulate the test mse
# Out:
# Training MSE is  0.0

# %%
#plotting the tree

dot_data = tree.export_graphviz(model, out_file=None, 
                                feature_names=X_train.columns,  
                                filled=True)
# Draw graph
graph = graphviz.Source(dot_data) 
display(HTML(graph._repr_svg_()))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: Tree Pages: 1 -->
# <svg width="9677pt" height="1621pt"
#  viewBox="0.00 0.00 9677.00 1621.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1617)">
# <title>Tree</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-1617 9673,-1617 9673,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <polygon fill="#f3c4a3" stroke="black" points="2042,-1613 1925,-1613 1925,-1545 2042,-1545 2042,-1613"/>
# <text text-anchor="middle" x="1983.5" y="-1597.8" font-family="Times New Roman,serif" font-size="14.00">ShelveLoc &lt;= 0.5</text>
# <text text-anchor="middle" x="1983.5" y="-1582.8" font-family="Times New Roman,serif" font-size="14.00">mse = 8.272</text>
# <text text-anchor="middle" x="1983.5" y="-1567.8" font-family="Times New Roman,serif" font-size="14.00">samples = 200</text>
# <text text-anchor="middle" x="1983.5" y="-1552.8" font-family="Times New Roman,serif" font-size="14.00">value = 7.554</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <polygon fill="#f7d8c1" stroke="black" points="1069,-1509 976,-1509 976,-1441 1069,-1441 1069,-1509"/>
# <text text-anchor="middle" x="1022.5" y="-1493.8" font-family="Times New Roman,serif" font-size="14.00">Price &lt;= 88.5</text>
# <text text-anchor="middle" x="1022.5" y="-1478.8" font-family="Times New Roman,serif" font-size="14.00">mse = 5.434</text>
# <text text-anchor="middle" x="1022.5" y="-1463.8" font-family="Times New Roman,serif" font-size="14.00">samples = 50</text>
# <text text-anchor="middle" x="1022.5" y="-1448.8" font-family="Times New Roman,serif" font-size="14.00">value = 5.228</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M1924.83,-1571.77C1752.41,-1553.47 1248.75,-1500.01 1079.06,-1482"/>
# <polygon fill="black" stroke="black" points="1079.4,-1478.52 1069.09,-1480.94 1078.66,-1485.48 1079.4,-1478.52"/>
# <text text-anchor="middle" x="1084.8" y="-1496.69" font-family="Times New Roman,serif" font-size="14.00">True</text>
# </g>
# <!-- 98 -->
# <g id="node99" class="node"><title>98</title>
# <polygon fill="#f2be99" stroke="black" points="3025.5,-1509 2925.5,-1509 2925.5,-1441 3025.5,-1441 3025.5,-1509"/>
# <text text-anchor="middle" x="2975.5" y="-1493.8" font-family="Times New Roman,serif" font-size="14.00">Price &lt;= 109.5</text>
# <text text-anchor="middle" x="2975.5" y="-1478.8" font-family="Times New Roman,serif" font-size="14.00">mse = 6.812</text>
# <text text-anchor="middle" x="2975.5" y="-1463.8" font-family="Times New Roman,serif" font-size="14.00">samples = 150</text>
# <text text-anchor="middle" x="2975.5" y="-1448.8" font-family="Times New Roman,serif" font-size="14.00">value = 8.33</text>
# </g>
# <!-- 0&#45;&gt;98 -->
# <g id="edge98" class="edge"><title>0&#45;&gt;98</title>
# <path fill="none" stroke="black" d="M2042.22,-1571.96C2217.79,-1553.91 2737.6,-1500.46 2915.21,-1482.2"/>
# <polygon fill="black" stroke="black" points="2915.83,-1485.65 2925.41,-1481.15 2915.11,-1478.69 2915.83,-1485.65"/>
# <text text-anchor="middle" x="2909.64" y="-1496.84" font-family="Times New Roman,serif" font-size="14.00">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node"><title>2</title>
# <polygon fill="#f1bb94" stroke="black" points="645,-1405 552,-1405 552,-1337 645,-1337 645,-1405"/>
# <text text-anchor="middle" x="598.5" y="-1389.8" font-family="Times New Roman,serif" font-size="14.00">Price &lt;= 85.5</text>
# <text text-anchor="middle" x="598.5" y="-1374.8" font-family="Times New Roman,serif" font-size="14.00">mse = 2.271</text>
# <text text-anchor="middle" x="598.5" y="-1359.8" font-family="Times New Roman,serif" font-size="14.00">samples = 5</text>
# <text text-anchor="middle" x="598.5" y="-1344.8" font-family="Times New Roman,serif" font-size="14.00">value = 8.708</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge"><title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M975.912,-1462.79C897.564,-1443.94 739.716,-1405.97 655.11,-1385.62"/>
# <polygon fill="black" stroke="black" points="655.707,-1382.16 645.165,-1383.23 654.069,-1388.97 655.707,-1382.16"/>
# </g>
# <!-- 11 -->
# <g id="node12" class="node"><title>11</title>
# <polygon fill="#f8dbc6" stroke="black" points="1068.5,-1405 976.5,-1405 976.5,-1337 1068.5,-1337 1068.5,-1405"/>
# <text text-anchor="middle" x="1022.5" y="-1389.8" font-family="Times New Roman,serif" font-size="14.00">Age &lt;= 43.0</text>
# <text text-anchor="middle" x="1022.5" y="-1374.8" font-family="Times New Roman,serif" font-size="14.00">mse = 4.29</text>
# <text text-anchor="middle" x="1022.5" y="-1359.8" font-family="Times New Roman,serif" font-size="14.00">samples = 45</text>
# <text text-anchor="middle" x="1022.5" y="-1344.8" font-family="Times New Roman,serif" font-size="14.00">value = 4.841</text>
# </g>
# <!-- 1&#45;&gt;11 -->
# <g id="edge11" class="edge"><title>1&#45;&gt;11</title>
# <path fill="none" stroke="black" d="M1022.5,-1440.88C1022.5,-1432.78 1022.5,-1423.98 1022.5,-1415.47"/>
# <polygon fill="black" stroke="black" points="1026,-1415.3 1022.5,-1405.3 1019,-1415.3 1026,-1415.3"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node"><title>3</title>
# <polygon fill="#f2c19d" stroke="black" points="388,-1301 257,-1301 257,-1233 388,-1233 388,-1301"/>
# <text text-anchor="middle" x="322.5" y="-1285.8" font-family="Times New Roman,serif" font-size="14.00">Population &lt;= 166.0</text>
# <text text-anchor="middle" x="322.5" y="-1270.8" font-family="Times New Roman,serif" font-size="14.00">mse = 0.097</text>
# <text text-anchor="middle" x="322.5" y="-1255.8" font-family="Times New Roman,serif" font-size="14.00">samples = 4</text>
# <text text-anchor="middle" x="322.5" y="-1240.8" font-family="Times New Roman,serif" font-size="14.00">value = 7.968</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge3" class="edge"><title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M551.992,-1352.81C509.865,-1337.24 447.033,-1314.02 397.759,-1295.81"/>
# <polygon fill="black" stroke="black" points="398.688,-1292.43 388.095,-1292.24 396.262,-1298.99 398.688,-1292.43"/>
# </g>
# <!-- 10 -->
# <g id="node11" class="node"><title>10</title>
# <polygon fill="#eca26d" stroke="black" points="644.5,-1293.5 552.5,-1293.5 552.5,-1240.5 644.5,-1240.5 644.5,-1293.5"/>
# <text text-anchor="middle" x="598.5" y="-1278.3" font-family="Times New Roman,serif" font-size="14.00">mse = &#45;0.0</text>
# <text text-anchor="middle" x="598.5" y="-1263.3" font-family="Times New Roman,serif" font-size="14.00">samples = 1</text>
# <text text-anchor="middle" x="598.5" y="-1248.3" font-family="Times New Roman,serif" font-size="14.00">value = 11.67</text>
# </g>
# <!-- 2&#45;&gt;10 -->
# <g id="edge10" class="edge"><title>2&#45;&gt;10</title>
# <path fill="none" stroke="black" d="M598.5,-1336.88C598.5,-1326.33 598.5,-1314.6 598.5,-1303.85"/>
# <polygon fill="black" stroke="black" points="602,-1303.52 598.5,-1293.52 595,-1303.52 602,-1303.52"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node"><title>4</title>
# <polygon fill="#f1bd98" stroke="black" points="240,-1189.5 155,-1189.5 155,-1136.5 240,-1136.5 240,-1189.5"/>
# <text text-anchor="middle" x="197.5" y="-1174.3" font-family="Times New Roman,serif" font-size="14.00">mse = 0.0</text>
# <text text-anchor="middle" x="197.5" y="-1159.3" font-family="Times New Roman,serif" font-size="14.00">samples = 1</text>
# <text text-anchor="middle" x="197.5" y="-1144.3" font-family="Times New Roman,serif" font-size="14.00">value = 8.39</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge4" class="edge"><title>3&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M281.916,-1232.88C267.36,-1221.01 250.988,-1207.65 236.564,-1195.88"/>
# <polygon fill="black" stroke="black" points="238.735,-1193.13 228.774,-1189.52 234.309,-1198.55 238.735,-1193.13"/>
# </g>
# <!-

# %% [markdown]
# The above tree is a very very complex tree, that is because i didn;t specified any max_depth. normally optimal max_depth ranges from 3-6, so, will have to see that

# %%
#test mse 
print('Test MSE is ',mean_squared_error(y_test,model.predict(X_test)))
print('Test R2 score is ',model.score(X_test,y_test)) # it is pretty poor
# Out:
# Test MSE is  5.41834
# Test R2 score is  0.29013304323126277

# %% [markdown]
# ### (c) Use cross-validation in order to determine the optimal level of tree complexity. Does pruning the tree improve the test MSE?

# %%
scores_dict = {}
for max_depth in range(1,10):
    model = DecisionTreeRegressor(max_depth=max_depth)
    scores_dict[max_depth] = -np.mean(cross_val_score(model,X_train,y_train,scoring = 'neg_mean_squared_error',cv=10))

# %%
plt.figure(figsize = (10,6))
plt.plot(list(scores_dict.keys()),list(scores_dict.values()),marker = 'o')
plt.plot(min(scores_dict, key=scores_dict.get),min(list(scores_dict.values())),marker = 'o',markersize = 8,c='r',label = 'min_error')
plt.legend()
plt.xlabel('Max Depth')
plt.ylabel('10 CV Error')
# Out:
# Text(0, 0.5, '10 CV Error')

# %%
# from the above graph, we get 4 as the best value of max_depth
best_model = DecisionTreeRegressor(max_depth = 4)
best_model.fit(X_train,y_train)
print('Training MSE is ',mean_squared_error(y_train,best_model.predict(X_train)))
print('Test MSE is ',mean_squared_error(y_test,best_model.predict(X_test)))
# Out:
# Training MSE is  2.248628264587724
# Test MSE is  4.8159413321452424

# %% [markdown]
# Test MSE has decreases from 5.41834 to 4.82. That's great!

# %% [markdown]
# ### Lets analyze this tree

# %%
#plotting the tree

dot_data = tree.export_graphviz(best_model, out_file=None, 
                                feature_names=X_train.columns,  
                                filled=True)
# Draw graph
graph = graphviz.Source(dot_data) 
display(HTML(graph._repr_svg_()))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: Tree Pages: 1 -->
# <svg width="1558pt" height="477pt"
#  viewBox="0.00 0.00 1557.50 477.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 473)">
# <title>Tree</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-473 1553.5,-473 1553.5,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <polygon fill="#f2c29f" stroke="black" points="723,-469 606,-469 606,-401 723,-401 723,-469"/>
# <text text-anchor="middle" x="664.5" y="-453.8" font-family="Times New Roman,serif" font-size="14.00">ShelveLoc &lt;= 0.5</text>
# <text text-anchor="middle" x="664.5" y="-438.8" font-family="Times New Roman,serif" font-size="14.00">mse = 8.272</text>
# <text text-anchor="middle" x="664.5" y="-423.8" font-family="Times New Roman,serif" font-size="14.00">samples = 200</text>
# <text text-anchor="middle" x="664.5" y="-408.8" font-family="Times New Roman,serif" font-size="14.00">value = 7.554</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <polygon fill="#f8dcc8" stroke="black" points="494,-365 401,-365 401,-297 494,-297 494,-365"/>
# <text text-anchor="middle" x="447.5" y="-349.8" font-family="Times New Roman,serif" font-size="14.00">Price &lt;= 88.5</text>
# <text text-anchor="middle" x="447.5" y="-334.8" font-family="Times New Roman,serif" font-size="14.00">mse = 5.434</text>
# <text text-anchor="middle" x="447.5" y="-319.8" font-family="Times New Roman,serif" font-size="14.00">samples = 50</text>
# <text text-anchor="middle" x="447.5" y="-304.8" font-family="Times New Roman,serif" font-size="14.00">value = 5.228</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M605.777,-406.397C573.903,-391.415 534.713,-372.994 503.304,-358.23"/>
# <polygon fill="black" stroke="black" points="504.784,-355.059 494.245,-353.972 501.806,-361.394 504.784,-355.059"/>
# <text text-anchor="middle" x="502.723" y="-373.791" font-family="Times New Roman,serif" font-size="14.00">True</text>
# </g>
# <!-- 14 -->
# <g id="node15" class="node"><title>14</title>
# <polygon fill="#f1b991" stroke="black" points="936.5,-365 836.5,-365 836.5,-297 936.5,-297 936.5,-365"/>
# <text text-anchor="middle" x="886.5" y="-349.8" font-family="Times New Roman,serif" font-size="14.00">Price &lt;= 109.5</text>
# <text text-anchor="middle" x="886.5" y="-334.8" font-family="Times New Roman,serif" font-size="14.00">mse = 6.812</text>
# <text text-anchor="middle" x="886.5" y="-319.8" font-family="Times New Roman,serif" font-size="14.00">samples = 150</text>
# <text text-anchor="middle" x="886.5" y="-304.8" font-family="Times New Roman,serif" font-size="14.00">value = 8.33</text>
# </g>
# <!-- 0&#45;&gt;14 -->
# <g id="edge14" class="edge"><title>0&#45;&gt;14</title>
# <path fill="none" stroke="black" d="M723.118,-407.067C755.154,-392.348 794.744,-374.158 826.928,-359.371"/>
# <polygon fill="black" stroke="black" points="828.602,-362.454 836.228,-355.098 825.68,-356.093 828.602,-362.454"/>
# <text text-anchor="middle" x="827.545" y="-374.842" font-family="Times New Roman,serif" font-size="14.00">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node"><title>2</title>
# <polygon fill="#f0b58b" stroke="black" points="312,-261 219,-261 219,-193 312,-193 312,-261"/>
# <text text-anchor="middle" x="265.5" y="-245.8" font-family="Times New Roman,serif" font-size="14.00">Price &lt;= 85.5</text>
# <text text-anchor="middle" x="265.5" y="-230.8" font-family="Times New Roman,serif" font-size="14.00">mse = 2.271</text>
# <text text-anchor="middle" x="265.5" y="-215.8" font-family="Times New Roman,serif" font-size="14.00">samples = 5</text>
# <text text-anchor="middle" x="265.5" y="-200.8" font-family="Times New Roman,serif" font-size="14.00">value = 8.708</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge"><title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M400.63,-303.732C376.323,-290.11 346.473,-273.38 321.016,-259.113"/>
# <polygon fill="black" stroke="black" points="322.645,-256.014 312.211,-254.179 319.223,-262.121 322.645,-256.014"/>
# </g>
# <!-- 7 -->
# <g id="node8" class="node"><title>7</title>
# <polygon fill="#f9e0cf" stroke="black" points="493.5,-261 401.5,-261 401.5,-193 493.5,-193 493.5,-261"/>
# <text text-anchor="middle" x="447.5" y="-245.8" font-family="Times New Roman,serif" font-size="14.00">Age &lt;= 43.0</text>
# <text text-anchor="middle" x="447.5" y="-230.8" font-family="Times New Roman,serif" font-size="14.00">mse = 4.29</text>
# <text text-anchor="middle" x="447.5" y="-215.8" font-family="Times New Roman,serif" font-size="14.00">samples = 45</text>
# <text text-anchor="middle" x="447.5" y="-200.8" font-family="Times New Roman,serif" font-size="14.00">value = 4.841</text>
# </g>
# <!-- 1&#45;&gt;7 -->
# <g id="edge7" class="edge"><title>1&#45;&gt;7</title>
# <path fill="none" stroke="black" d="M447.5,-296.884C447.5,-288.778 447.5,-279.982 447.5,-271.472"/>
# <polygon fill="black" stroke="black" points="451,-271.299 447.5,-261.299 444,-271.299 451,-271.299"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node"><title>3</title>
# <polygon fill="#f1bd98" stroke="black" points="201.5,-157 79.5,-157 79.5,-89 201.5,-89 201.5,-157"/>
# <text text-anchor="middle" x="140.5" y="-141.8" font-family="Times New Roman,serif" font-size="14.00">Advertising &lt;= 6.5</text>
# <text text-anchor="middle" x="140.5" y="-126.8" font-family="Times New Roman,serif" font-size="14.00">mse = 0.097</text>
# <text text-anchor="middle" x="140.5" y="-111.8" font-family="Times New Roman,serif" font-size="14.00">samples = 4</text>
# <text text-anchor="middle" x="140.5" y="-96.8" font-family="Times New Roman,serif" font-size="14.00">value = 7.968</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge3" class="edge"><title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M224.916,-192.884C213.564,-183.62 201.106,-173.455 189.33,-163.845"/>
# <polygon fill="black" stroke="black" points="191.269,-160.91 181.308,-157.299 186.843,-166.333 191.269,-160.91"/>
# </g>
# <!-- 6 -->
# <g id="node7" class="node"><title>6</title>
# <polygon fill="#e99457" stroke="black" points="311.5,-149.5 219.5,-149.5 219.5,-96.5 311.5,-96.5 311.5,-149.5"/>
# <text text-anchor="middle" x="265.5" y="-134.3" font-family="Times New Roman,serif" font-size="14.00">mse = &#45;0.0</text>
# <text text-anchor="middle" x="265.5" y="-119.3" font-family="Times New Roman,serif" font-size="14.00">samples = 1</text>
# <text text-anchor="middle" x="265.5" y="-104.3" font-family="Times New Roman,serif" font-size="14.00">value = 11.67</text>
# </g>
# <!-- 2&#45;&gt;6 -->
# <g id="edge6" class="edge"><title>2&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M265.5,-192.884C265.5,-182.326 265.5,-170.597 265.5,-159.854"/>
# <polygon fill="black" stroke="black" points="269,-159.52 265.5,-149.52 262,-159.52 269,-159.52"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node"><title>4</title>
# <polygon fill="#f0b990" stroke="black" points="85,-53 0,-53 0,-0 85,-0 85,-53"/>
# <text text-anchor="middle" x="42.5" y="-37.8" font-family="Times New Roman,serif" font-size="14.00">mse = 0.0</text>
# <text text-anchor="middle" x="42.5" y="-22.8" font-family="Times New Roman,serif" font-size="14.00">samples = 1</text>
# <text text-anchor="middle" x="42.5" y="-7.8" font-family="Times New Roman,serif" font-size="14.00">value = 8.39</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge4" class="edge"><title>3&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M106.224,-88.9485C96.6427,-79.709 86.2329,-69.671 76.658,-60.4381"/>
# <polygon fill="black" stroke="black" points="78.8179,-57.6586 69.1899,-53.2367 73.9589,-62.6976 78.8179,-57.6586"/>
# </g>
# <!-- 5 -->
# <g id="node6" class="node"><title>5</title>
# <polygon fill="#f2bf9a" stroke="black" points="195.5,-53 103.5,-53 103.5,-0 195.5,-0 195.5,-53"/>
# <te

# %%
# feature importance for best model
pd.Series(best_model.feature_importances_,index = X_train.columns).sort_values(ascending=False).plot.bar()

# %% [markdown]
# From the above graph it is clear that Shelveloc and Price are the most important features to detect the price. So, if someone is starting a new store, just make sure the shelveLoc is Good!

# %% [markdown]
# ### (d) Use the bagging approach in order to analyze this data. What test MSE do you obtain? Use the importance() function to determine which variables are most important.

# %%
base_reg = DecisionTreeRegressor()
bagging = BaggingRegressor(base_reg)
bagging.fit(X_train,y_train)
print('Training MSE ',mean_squared_error(y_train,bagging.predict(X_train)))
print('Test MSE ',mean_squared_error(y_test,bagging.predict(X_test)))
# Out:
# Training MSE  0.5279924899999999
# Test MSE  3.15803521

# %% [markdown]
# Using bagging we are getting a significant decrease in MSE to 1.15

# %%
# going through each of the estimator in bagging model to calculate feature importance
feature_importances = np.mean([tree.feature_importances_ for tree in bagging.estimators_], axis=0)
pd.Series(feature_importances,index = X_train.columns).sort_values(ascending=False).plot.bar()

# %% [markdown]
# Unlike the decision tree regressor, bagging model gives similar importance to ShelveLoc and Price, infact here importnace of Price is slightly greater than ShelveLoc. So, if someone is starting a new store, we would suggest - "hey buddy, keep the condition of ShelveLoc good, but keep the price reasonable too" :D

# %% [markdown]
# ### (e) Use random forests to analyze this data. What test MSE do you obtain? Use the importance() function to determine which variables are most important. Describe the effect of m, the number of variables considered at each split, on the error rate obtained.

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
print('Training MSE is ',mean_squared_error(y_train,rf.predict(X_train)))
print('Test MSE is ',mean_squared_error(y_test,rf.predict(X_test)))
# Out:
# Training MSE is  0.555589415
# Test MSE is  2.9681447249999997
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# Woah, random forest further decreases MSE to 2.968

# %%
#feature importance
pd.Series(rf.feature_importances_,index = X_train.columns).sort_values(ascending=False).plot.bar()

# %% [markdown]
# We can see that the feature importance plot is quite similar to the one we got from bagging model.

# %% [markdown]
# ### Effect of max_features (m)

# %%
scores_dict = {}
for max_feature_value in range(1,11):
    rf = RandomForestRegressor(max_features=max_feature_value)
    rf.fit(X_train,y_train)
    scores_dict[max_feature_value] = mean_squared_error(y_test,rf.predict(X_test))

# %%
plt.figure(figsize = (10,6))
plt.plot(list(scores_dict.keys()),list(scores_dict.values()),marker = 'o')
plt.plot(min(scores_dict, key=scores_dict.get),min(list(scores_dict.values())),marker = 'o',markersize = 8,c='r',label = 'min_error')
plt.legend()
plt.xlabel('Number of features considered for each split')
plt.ylabel('Test Error')
# Out:
# Text(0, 0.5, 'Test Error')

# %% [markdown]
# We are getting best value when the value of the parameter is 7.

# %% [markdown]
# ## 9. This problem involves the OJ data set which is part of the ISLR package.

# %%
data = pd.read_csv('E:\programming\dataset\Into_to_statstical_learning\OJ.csv',index_col=0)
print(data.shape)
data.head()
# Out:
# (1070, 18)
#   Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 1       CH             237        1     1.75     1.99    0.00     0.0
# 2       CH             239        1     1.75     1.99    0.00     0.3
# 3       CH             245        1     1.86     2.09    0.17     0.0
# 4       MM             227        1     1.69     1.69    0.00     0.0
# 5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 1          0          0  0.500000         1.99         1.75       0.24     No
# 2          0          1  0.600000         1.69         1.75      -0.06     No
# 3          0          0  0.680000         2.09         1.69       0.40     No
# 4          0          0  0.400000         1.69         1.69       0.00     No
# 5          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 1   0.000000   0.000000           0.24      1
# 2   0.150754   0.000000           0.24      1
# 3   0.000000   0.091398           0.23      1
# 4   0.000000   0.000000           0.00      1
# 5   0.000000   0.000000           0.00      0

# %% [markdown]
# Lets go through the dataset, and see what it describes
# - Purchase-A factor with levels CH and MM indicating whether the customer purchased Citrus Hill or Minute Maid Orange Juice
#
# - WeekofPurchase - Week of purchase
# - StoreID-Store ID
# - PriceCH-Price charged for CH
# - PriceMM-Price charged for MM
# - DiscCH-Discount offered for CH
# - DiscMM-Discount offered for MM
# - SpecialCH-Indicator of special on CH
# - SpecialMM-Indicator of special on MM
# - LoyalCH-Customer brand loyalty for CH
# - SalePriceMM-Sale price for MM
# - SalePriceCH-Sale price for CH
# - PriceDiff-Sale price of MM less sale price of CH
# - Store7-A factor with levels No and Yes indicating whether the sale is at Store 7
# - PctDiscMM-Percentage discount for MM
# - PctDiscCH-Percentage discount for CH
# - ListPriceDiff-List price of MM less list price of CH
# - STORE-Which of 5 possible stores the sale occured at

# %%
data['Purchase'].value_counts()
# Out:
# CH    653
# MM    417
# Name: Purchase, dtype: int64

# %% [markdown]
# We can guess from the dataset, that the problem we are having involves a number of predictors, and we want to predict whether a customer will go for CH(citrus hill), or mm(minute maid)

# %%
#encoding the categorical columns
data['Purchase'] = data['Purchase'].map({'CH':0,'MM':1})
data['Store7'] = data['Store7'].map({'Yes':1,'No':0})
data.head()
# Out:
#    Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 1         0             237        1     1.75     1.99    0.00     0.0
# 2         0             239        1     1.75     1.99    0.00     0.3
# 3         0             245        1     1.86     2.09    0.17     0.0
# 4         1             227        1     1.69     1.69    0.00     0.0
# 5         0             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff  \
# 1          0          0  0.500000         1.99         1.75       0.24
# 2          0          1  0.600000         1.69         1.75      -0.06
# 3          0          0  0.680000         2.09         1.69       0.40
# 4          0          0  0.400000         1.69         1.69       0.00
# 5          0          0  0.956535         1.69         1.69       0.00
#
#    Store7  PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 1       0   0.000000   0.000000           0.24      1
# 2       0   0.150754   0.000000           0.24      1
# 3       0   0.000000   0.091398           0.23      1
# 4       0   0.000000   0.000000           0.00      1
# 5       1   0.000000   0.000000           0.00      0

# %% [markdown]
# ### (a) Create a training set containing a random sample of 800 observations, and a test set containing the remaining observations.

# %%
X_train,X_test,y_train,y_test = train_test_split(data.drop('Purchase',axis=1),data['Purchase'],test_size = 0.2523,random_state=1)
print(X_train.shape,X_test.shape)
#i have used test_size = 270 / 1070, such that training data has 800 observations
# Out:
# (800, 17) (270, 17)

# %% [markdown]
# ### (b) Fit a tree to the training data, with Purchase as the response and the other variables except for Buy as predictors. Use the summary() function to produce summary statistics about the tree, and describe the results obtained. What is the training error rate? How many terminal nodes does the tree have?

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
print('Training Error rate ',1 - model.score(X_train,y_train))
# Out:
# Training Error rate  0.010000000000000009

# %% [markdown]
# One thing i have observed is that if we don;t specify any max_depth, or any other parameter that acts like a stopping condition, the tree is most likely to overfit, looking at the training error here, it seems to be the same.

# %% [markdown]
# ### (c) Type in the name of the tree object in order to get a detailed text output. Pick one of the terminal nodes, and interpret the information displayed.

# %%
# this is the closest i can find
print(tree.export_text(model))
# Out:
# |--- feature_8 <= 0.45
# |   |--- feature_8 <= 0.28
# |   |   |--- feature_8 <= 0.05
# |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |--- feature_8 <= 0.00
# |   |   |   |   |   |--- feature_0 <= 269.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  269.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  0.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |--- class: 1
# |   |   |--- feature_8 >  0.05
# |   |   |   |--- feature_0 <= 249.50
# |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |--- feature_0 <= 235.50
# |   |   |   |   |   |   |--- feature_0 <= 232.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  232.00
# |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.22
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.22
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  235.50
# |   |   |   |   |   |   |--- feature_5 <= 0.10
# |   |   |   |   |   |   |   |--- feature_8 <= 0.13
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  0.13
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  0.10
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |--- feature_8 <= 0.07
# |   |   |   |   |   |   |--- feature_15 <= 0.27
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_15 >  0.27
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.07
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  249.50
# |   |   |   |   |--- feature_0 <= 273.50
# |   |   |   |   |   |--- feature_2 <= 1.88
# |   |   |   |   |   |   |--- feature_8 <= 0.18
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  0.18
# |   |   |   |   |   |   |   |--- feature_8 <= 0.20
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  0.20
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.48
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 272.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  272.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.48
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  1.88
# |   |   |   |   |   |   |--- feature_7 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 261.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.27
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.27
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  261.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_7 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  273.50
# |   |   |   |   |   |--- class: 1
# |   |--- feature_8 >  0.28
# |   |   |--- feature_6 <= 0.50
# |   |   |   |--- feature_9 <= 2.04
# |   |   |   |   |--- feature_8 <= 0.28
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  0.28
# |   |   |   |   |   |--- feature_0 <= 276.50
# |   |   |   |   |   |   |--- feature_3 <= 2.04
# |   |   |   |   |   |   |   |--- feature_12 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 264.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  264.00
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_12 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.72
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.72
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  2.04
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  276.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_9 >  2.04
# |   |   |   |   |--- feature_8 <= 0.30
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  0.30
# |   |   |   |   |   |--- feature_10 <= 1.77
# |   |   |   |   |   |   |--- feature_8 <= 0.33
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.33
# |   |   |   |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.34
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.34
# |   |   |   |   |   |   |   |   |   |--- feature_14 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 252.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  252.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_14 >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_10 >  1.77
# |   |   |   |   |   |   |--- feature_8 <= 0.33
# |   |   |   |   |   |   |   |--- feature_0 <= 269.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  269.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.93
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.93
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  0.33
# |   |   |   |   |   |   |   |--- feature_0 <= 269.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.42
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 243.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  243.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.42
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  269.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_6 >  0.50
# |   |   |   |--- feature_8 <= 0.41
# |   |   |   |   |--- feature_11 <= -0.13
# |   |   |   |   |   |--- feature_8 <= 0.37
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  0.37
# |   |   |   |   |   |   |--- feature_11 <= -0.18
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_11 >  -0.18
# |   |   |   |   |   |   |   |--- feature_8 <= 0.39
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  0.39
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_11 >  -0.13
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_8 >  0.41
# |   |   |   |   |--- feature_0 <= 248.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  248.50
# |   |   |   |   |   |--- class: 1
# |--- feature_8 >  0.45
# |   |--- feature_8 <= 0.75
# |   |   |--- feature_11 <= -0.16
# |   |   |   |--- feature_16 <= 2.50
# |   |   |   |   |--- feature_9 <= 1.54
# |   |   |   |   |   |--- feature_8 <= 0.59
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  0.59
# |   |   |   |   |   |   |--- feature_8 <= 0.71
# |   |   |   |   |   |   |   |--- feature_9 <= 1.38
# |   |   |   |   |   |   |   |   |--- feature_13 <= 0.38
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_13 >  0.38
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  1.38
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.71
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_9 >  1.54
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_16 >  2.50
# |   |   |   |   |--- feature_8 <= 0.52
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  0.52
# |   |   |   |   |   |--- feature_8 <= 0.75
# |   |   |   |   |   |   |--- feature_8 <= 0.61
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.61
# |   |   |   |   |   |   |   |--- feature_8 <= 0.68
# |   |   |   |   |   |   |   |   |--- feature_0 <= 271.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  271.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  0.68
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.75
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_11 >  -0.16
# |   |   |   |--- feature_9 <= 2.12
# |   |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |   |--- feature_14 <= 0.03
# |   |   |   |   |   |   |--- feature_2 <= 1.72
# |   |   |   |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  1.72
# |   |   |   |   |   |   |   |--- feature_11 <= 0.23
# |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 242.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  242.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_11 >  0.23
# |   |   |   |   |   |   |   |   |--- feature_0 <= 252.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  252.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_14 >  0.03
# |   |   |   |   |   |   |--- feature_0 <= 252.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  252.50
# |   |   |   |   |   |   |   |--- feature_11 <= 0.27
# |   |   |   |   |   |   |   |   |--- feature_1 <= 5.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  5.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_11 >  0.27
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |   |--- feature_8 <= 0.65
# |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 233.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 228.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  228.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  233.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= -0.06
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_11 >  -0.06
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 272.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 236.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  236.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  272.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |--- feature_11 <= 0.32
# |   |   |   |   |   |   |   |   |--- feature_11 <= -0.13
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.58
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.58
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 233.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  233.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_11 >  -0.13
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_11 >  0.32
# |   |   |   |   |   |   |   |   |--- feature_0 <= 251.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  251.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.65
# |   |   |   |   |   |   |--- feature_0 <= 266.50
# |   |   |   |   |   |   |   |--- feature_8 <= 0.71
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1.74
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  1.74
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.69
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  0.71
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  266.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_9 >  2.12
# |   |   |   |   |--- feature_0 <= 241.50
# |   |   |   |   |   |--- feature_8 <= 0.57
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  0.57
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  241.50
# |   |   |   |   |   |--- feature_0 <= 261.50
# |   |   |   |   |   |   |--- feature_0 <= 260.00
# |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.74
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.74
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.03
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.59
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.59
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  260.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  261.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- feature_8 >  0.75
# |   |   |--- feature_11 <= -0.39
# |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |--- feature_8 <= 1.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  1.00
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_11 >  -0.39
# |   |   |   |--- feature_0 <= 241.50
# |   |   |   |   |--- feature_0 <= 236.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  236.50
# |   |   |   |   |   |--- feature_8 <= 0.93
# |   |   |   |   |   |   |--- feature_0 <= 238.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.77
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  1.77
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  238.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.93
# |   |   |   |   |   |   |--- feature_8 <= 0.98
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  0.98
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  241.50
# |   |   |   |   |--- feature_9 <= 2.26
# |   |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |   |--- feature_0 <= 263.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  263.50
# |   |   |   |   |   |   |   |--- feature_0 <= 264.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.96
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.96
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  264.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.88
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.87
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.87
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_9 >  2.26
# |   |   |   |   |   |--- feature_0 <= 254.50
# |   |   |   |   |   |   |--- feature_8 <= 0.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  0.92
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  254.50
# |   |   |   |   |   |   |--- class: 0

# %% [markdown]
# ### (d) Create a plot of the tree, and interpret the results.

# %%
#plotting the tree

dot_data = tree.export_graphviz(model, out_file=None, 
                                feature_names=X_train.columns,  
                                filled=True)
# Draw graph
graph = graphviz.Source(dot_data) 
display(HTML(graph._repr_svg_()))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: Tree Pages: 1 -->
# <svg width="6901pt" height="1725pt"
#  viewBox="0.00 0.00 6901.00 1725.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1721)">
# <title>Tree</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-1721 6897,-1721 6897,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <polygon fill="#f5ceb2" stroke="black" points="3156.5,-1717 3034.5,-1717 3034.5,-1649 3156.5,-1649 3156.5,-1717"/>
# <text text-anchor="middle" x="3095.5" y="-1701.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.454</text>
# <text text-anchor="middle" x="3095.5" y="-1686.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.471</text>
# <text text-anchor="middle" x="3095.5" y="-1671.8" font-family="Times New Roman,serif" font-size="14.00">samples = 800</text>
# <text text-anchor="middle" x="3095.5" y="-1656.8" font-family="Times New Roman,serif" font-size="14.00">value = [496, 304]</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <polygon fill="#75bbed" stroke="black" points="2372.5,-1613 2250.5,-1613 2250.5,-1545 2372.5,-1545 2372.5,-1613"/>
# <text text-anchor="middle" x="2311.5" y="-1597.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.276</text>
# <text text-anchor="middle" x="2311.5" y="-1582.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.356</text>
# <text text-anchor="middle" x="2311.5" y="-1567.8" font-family="Times New Roman,serif" font-size="14.00">samples = 289</text>
# <text text-anchor="middle" x="2311.5" y="-1552.8" font-family="Times New Roman,serif" font-size="14.00">value = [67, 222]</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M3034.31,-1674.04C2891.19,-1655.42 2535.24,-1609.11 2382.72,-1589.27"/>
# <polygon fill="black" stroke="black" points="2382.9,-1585.76 2372.53,-1587.94 2382,-1592.7 2382.9,-1585.76"/>
# <text text-anchor="middle" x="2387.78" y="-1604.05" font-family="Times New Roman,serif" font-size="14.00">True</text>
# </g>
# <!-- 140 -->
# <g id="node141" class="node"><title>140</title>
# <polygon fill="#ea995f" stroke="black" points="3940.5,-1613 3818.5,-1613 3818.5,-1545 3940.5,-1545 3940.5,-1613"/>
# <text text-anchor="middle" x="3879.5" y="-1597.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.754</text>
# <text text-anchor="middle" x="3879.5" y="-1582.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.269</text>
# <text text-anchor="middle" x="3879.5" y="-1567.8" font-family="Times New Roman,serif" font-size="14.00">samples = 511</text>
# <text text-anchor="middle" x="3879.5" y="-1552.8" font-family="Times New Roman,serif" font-size="14.00">value = [429, 82]</text>
# </g>
# <!-- 0&#45;&gt;140 -->
# <g id="edge140" class="edge"><title>0&#45;&gt;140</title>
# <path fill="none" stroke="black" d="M3156.69,-1674.04C3299.81,-1655.42 3655.76,-1609.11 3808.28,-1589.27"/>
# <polygon fill="black" stroke="black" points="3809,-1592.7 3818.47,-1587.94 3808.1,-1585.76 3809,-1592.7"/>
# <text text-anchor="middle" x="3803.22" y="-1604.05" font-family="Times New Roman,serif" font-size="14.00">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node"><title>2</title>
# <polygon fill="#52a9e8" stroke="black" points="936.5,-1509 814.5,-1509 814.5,-1441 936.5,-1441 936.5,-1509"/>
# <text text-anchor="middle" x="875.5" y="-1493.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.051</text>
# <text text-anchor="middle" x="875.5" y="-1478.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.201</text>
# <text text-anchor="middle" x="875.5" y="-1463.8" font-family="Times New Roman,serif" font-size="14.00">samples = 168</text>
# <text text-anchor="middle" x="875.5" y="-1448.8" font-family="Times New Roman,serif" font-size="14.00">value = [19, 149]</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge"><title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M2250.26,-1573.65C2018.33,-1557.18 1194.55,-1498.66 946.612,-1481.05"/>
# <polygon fill="black" stroke="black" points="946.86,-1477.56 936.637,-1480.34 946.364,-1484.54 946.86,-1477.56"/>
# </g>
# <!-- 51 -->
# <g id="node52" class="node"><title>51</title>
# <polygon fill="#bbddf6" stroke="black" points="2370.5,-1509 2252.5,-1509 2252.5,-1441 2370.5,-1441 2370.5,-1509"/>
# <text text-anchor="middle" x="2311.5" y="-1493.8" font-family="Times New Roman,serif" font-size="14.00">SpecialCH &lt;= 0.5</text>
# <text text-anchor="middle" x="2311.5" y="-1478.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.479</text>
# <text text-anchor="middle" x="2311.5" y="-1463.8" font-family="Times New Roman,serif" font-size="14.00">samples = 121</text>
# <text text-anchor="middle" x="2311.5" y="-1448.8" font-family="Times New Roman,serif" font-size="14.00">value = [48, 73]</text>
# </g>
# <!-- 1&#45;&gt;51 -->
# <g id="edge51" class="edge"><title>1&#45;&gt;51</title>
# <path fill="none" stroke="black" d="M2311.5,-1544.88C2311.5,-1536.78 2311.5,-1527.98 2311.5,-1519.47"/>
# <polygon fill="black" stroke="black" points="2315,-1519.3 2311.5,-1509.3 2308,-1519.3 2315,-1519.3"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node"><title>3</title>
# <polygon fill="#3c9ee5" stroke="black" points="599.5,-1405 497.5,-1405 497.5,-1337 599.5,-1337 599.5,-1405"/>
# <text text-anchor="middle" x="548.5" y="-1389.8" font-family="Times New Roman,serif" font-size="14.00">StoreID &lt;= 2.5</text>
# <text text-anchor="middle" x="548.5" y="-1374.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.028</text>
# <text text-anchor="middle" x="548.5" y="-1359.8" font-family="Times New Roman,serif" font-size="14.00">samples = 71</text>
# <text text-anchor="middle" x="548.5" y="-1344.8" font-family="Times New Roman,serif" font-size="14.00">value = [1, 70]</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge3" class="edge"><title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M814.377,-1454.93C755.838,-1436.67 667.999,-1409.27 609.5,-1391.03"/>
# <polygon fill="black" stroke="black" points="610.242,-1387.59 599.653,-1387.96 608.158,-1394.28 610.242,-1387.59"/>
# </g>
# <!-- 10 -->
# <g id="node11" class="node"><title>10</title>
# <polygon fill="#66b3eb" stroke="black" points="959,-1405 792,-1405 792,-1337 959,-1337 959,-1405"/>
# <text text-anchor="middle" x="875.5" y="-1389.8" font-family="Times New Roman,serif" font-size="14.00">WeekofPurchase &lt;= 249.5</text>
# <text text-anchor="middle" x="875.5" y="-1374.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.302</text>
# <text text-anchor="middle" x="875.5" y="-1359.8" font-family="Times New Roman,serif" font-size="14.00">samples = 97</text>
# <text text-anchor="middle" x="875.5" y="-1344.8" font-family="Times New Roman,serif" font-size="14.00">value = [18, 79]</text>
# </g>
# <!-- 2&#45;&gt;10 -->
# <g id="edge10" class="edge"><title>2&#45;&gt;10</title>
# <path fill="none" stroke="black" d="M875.5,-1440.88C875.5,-1432.78 875.5,-1423.98 875.5,-1415.47"/>
# <polygon fill="black" stroke="black" points="879,-1415.3 875.5,-1405.3 872,-1415.3 879,-1415.3"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node"><title>4</title>
# <polygon fill="#49a5e7" stroke="black" points="380.5,-1301 258.5,-1301 258.5,-1233 380.5,-1233 380.5,-1301"/>
# <text text-anchor="middle" x="319.5" y="-1285.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.003</text>
# <text text-anchor="middle" x="319.5" y="-1270.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.142</text>
# <text text-anchor="middle" x="319.5" y="-1255.8" font-family="Times New Roman,serif" font-size="14.00">samples = 13</text>
# <text text-anchor="middle" x="319.5" y="-1240.8" font-family="Times New Roman,serif" font-size="14.00

# %% [markdown]
# One thing i can surely say is that this tree is too complex, and we would favour simpler tree than that (OCCAM's RAZOR)

# %% [markdown]
# ### (e) Predict the response on the test data, and produce a confusion matrix comparing the test labels to the predicted test labels. What is the test error rate?

# %%
y_preds = model.predict(X_test)
print('Test error is ',1 - accuracy_score(y_test,y_preds))
# Out:
# Test error is  0.2407407407407407

# %%
#confusion matrix 
cm = confusion_matrix(y_test,y_preds)
pd.DataFrame(cm,columns = ['Pred_0','Pred_2'],index = ['True_0','True_1'])
# Out:
#         Pred_0  Pred_2
# True_0     132      25
# True_1      40      73

# %% [markdown]
# ### (g) Produce a plot with tree size on the x-axis and cross-validated classification error rate on the y-axis.

# %%
cv_scores_dict = {}
for max_depth in range(1,15):
    model = DecisionTreeClassifier(max_depth=max_depth)
    cv_scores_dict[max_depth] = 1 - np.mean(cross_val_score(model,X_train,y_train,cv = 10))

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.figure(figsize = (10,6))
plt.plot(list(cv_scores_dict.keys()),list(cv_scores_dict.values()),marker = 'o')
plt.plot(min(cv_scores_dict, key=cv_scores_dict.get),min(list(cv_scores_dict.values())),marker = 'o',markersize = 8,c='r',label = 'min_error')
plt.legend()
plt.xlabel('Max Depth')
plt.ylabel('10 CV Error')
# Out:
# Text(0, 0.5, '10 CV Error')

# %% [markdown]
# ### (h) Which tree size corresponds to the lowest cross-validated classification error rate?

# %% [markdown]
# Tree with max_depth = 4, is giving the minimum cv error.

# %%
best_model = DecisionTreeClassifier(max_depth = 4)
best_model.fit(X_train,y_train)
dot_data = tree.export_graphviz(best_model, out_file=None, 
                                feature_names=X_train.columns,  
                                filled=True)
# Draw graph
graph = graphviz.Source(dot_data) 
display(HTML(graph._repr_svg_()))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: Tree Pages: 1 -->
# <svg width="1845pt" height="477pt"
#  viewBox="0.00 0.00 1845.00 477.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 473)">
# <title>Tree</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-473 1841,-473 1841,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <polygon fill="#f5ceb2" stroke="black" points="987,-469 865,-469 865,-401 987,-401 987,-469"/>
# <text text-anchor="middle" x="926" y="-453.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.454</text>
# <text text-anchor="middle" x="926" y="-438.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.471</text>
# <text text-anchor="middle" x="926" y="-423.8" font-family="Times New Roman,serif" font-size="14.00">samples = 800</text>
# <text text-anchor="middle" x="926" y="-408.8" font-family="Times New Roman,serif" font-size="14.00">value = [496, 304]</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <polygon fill="#75bbed" stroke="black" points="759,-365 637,-365 637,-297 759,-297 759,-365"/>
# <text text-anchor="middle" x="698" y="-349.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.276</text>
# <text text-anchor="middle" x="698" y="-334.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.356</text>
# <text text-anchor="middle" x="698" y="-319.8" font-family="Times New Roman,serif" font-size="14.00">samples = 289</text>
# <text text-anchor="middle" x="698" y="-304.8" font-family="Times New Roman,serif" font-size="14.00">value = [67, 222]</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M864.9,-406.666C835.254,-393.403 799.475,-377.397 768.66,-363.611"/>
# <polygon fill="black" stroke="black" points="769.826,-360.298 759.268,-359.41 766.967,-366.688 769.826,-360.298"/>
# <text text-anchor="middle" x="768.186" y="-379.065" font-family="Times New Roman,serif" font-size="14.00">True</text>
# </g>
# <!-- 16 -->
# <g id="node17" class="node"><title>16</title>
# <polygon fill="#ea995f" stroke="black" points="1215,-365 1093,-365 1093,-297 1215,-297 1215,-365"/>
# <text text-anchor="middle" x="1154" y="-349.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.754</text>
# <text text-anchor="middle" x="1154" y="-334.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.269</text>
# <text text-anchor="middle" x="1154" y="-319.8" font-family="Times New Roman,serif" font-size="14.00">samples = 511</text>
# <text text-anchor="middle" x="1154" y="-304.8" font-family="Times New Roman,serif" font-size="14.00">value = [429, 82]</text>
# </g>
# <!-- 0&#45;&gt;16 -->
# <g id="edge16" class="edge"><title>0&#45;&gt;16</title>
# <path fill="none" stroke="black" d="M987.1,-406.666C1016.75,-393.403 1052.52,-377.397 1083.34,-363.611"/>
# <polygon fill="black" stroke="black" points="1085.03,-366.688 1092.73,-359.41 1082.17,-360.298 1085.03,-366.688"/>
# <text text-anchor="middle" x="1083.81" y="-379.065" font-family="Times New Roman,serif" font-size="14.00">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node"><title>2</title>
# <polygon fill="#52a9e8" stroke="black" points="420,-261 298,-261 298,-193 420,-193 420,-261"/>
# <text text-anchor="middle" x="359" y="-245.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.051</text>
# <text text-anchor="middle" x="359" y="-230.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.201</text>
# <text text-anchor="middle" x="359" y="-215.8" font-family="Times New Roman,serif" font-size="14.00">samples = 168</text>
# <text text-anchor="middle" x="359" y="-200.8" font-family="Times New Roman,serif" font-size="14.00">value = [19, 149]</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge"><title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M636.61,-311.529C578.382,-294.009 490.941,-267.699 429.798,-249.302"/>
# <polygon fill="black" stroke="black" points="430.804,-245.95 420.219,-246.42 428.787,-252.653 430.804,-245.95"/>
# </g>
# <!-- 9 -->
# <g id="node10" class="node"><title>9</title>
# <polygon fill="#bbddf6" stroke="black" points="757,-261 639,-261 639,-193 757,-193 757,-261"/>
# <text text-anchor="middle" x="698" y="-245.8" font-family="Times New Roman,serif" font-size="14.00">SpecialCH &lt;= 0.5</text>
# <text text-anchor="middle" x="698" y="-230.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.479</text>
# <text text-anchor="middle" x="698" y="-215.8" font-family="Times New Roman,serif" font-size="14.00">samples = 121</text>
# <text text-anchor="middle" x="698" y="-200.8" font-family="Times New Roman,serif" font-size="14.00">value = [48, 73]</text>
# </g>
# <!-- 1&#45;&gt;9 -->
# <g id="edge9" class="edge"><title>1&#45;&gt;9</title>
# <path fill="none" stroke="black" d="M698,-296.884C698,-288.778 698,-279.982 698,-271.472"/>
# <polygon fill="black" stroke="black" points="701.5,-271.299 698,-261.299 694.5,-271.299 701.5,-271.299"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node"><title>3</title>
# <polygon fill="#3c9ee5" stroke="black" points="216,-157 114,-157 114,-89 216,-89 216,-157"/>
# <text text-anchor="middle" x="165" y="-141.8" font-family="Times New Roman,serif" font-size="14.00">StoreID &lt;= 2.5</text>
# <text text-anchor="middle" x="165" y="-126.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.028</text>
# <text text-anchor="middle" x="165" y="-111.8" font-family="Times New Roman,serif" font-size="14.00">samples = 71</text>
# <text text-anchor="middle" x="165" y="-96.8" font-family="Times New Roman,serif" font-size="14.00">value = [1, 70]</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge3" class="edge"><title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M297.883,-193.867C274.646,-181.649 248.21,-167.749 225.07,-155.583"/>
# <polygon fill="black" stroke="black" points="226.524,-152.393 216.044,-150.838 223.266,-158.589 226.524,-152.393"/>
# </g>
# <!-- 6 -->
# <g id="node7" class="node"><title>6</title>
# <polygon fill="#66b3eb" stroke="black" points="442.5,-157 275.5,-157 275.5,-89 442.5,-89 442.5,-157"/>
# <text text-anchor="middle" x="359" y="-141.8" font-family="Times New Roman,serif" font-size="14.00">WeekofPurchase &lt;= 249.5</text>
# <text text-anchor="middle" x="359" y="-126.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.302</text>
# <text text-anchor="middle" x="359" y="-111.8" font-family="Times New Roman,serif" font-size="14.00">samples = 97</text>
# <text text-anchor="middle" x="359" y="-96.8" font-family="Times New Roman,serif" font-size="14.00">value = [18, 79]</text>
# </g>
# <!-- 2&#45;&gt;6 -->
# <g id="edge6" class="edge"><title>2&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M359,-192.884C359,-184.778 359,-175.982 359,-167.472"/>
# <polygon fill="black" stroke="black" points="362.5,-167.299 359,-157.299 355.5,-167.299 362.5,-167.299"/>
# </g>
# <!-- 4 -->
# <g id="node5" class="node"><title>4</title>
# <polygon fill="#49a5e7" stroke="black" points="98,-53 0,-53 0,-0 98,-0 98,-53"/>
# <text text-anchor="middle" x="49" y="-37.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.142</text>
# <text text-anchor="middle" x="49" y="-22.8" font-family="Times New Roman,serif" font-size="14.00">samples = 13</text>
# <text text-anchor="middle" x="49" y="-7.8" font-family="Times New Roman,serif" font-size="14.00">value = [1, 12]</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge4" class="edge"><title>3&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M124.429,-88.9485C112.75,-79.4346 100.033,-69.074 88.4247,-59.6175"/>
# <polygon fill="black" stroke="black" points="90.5557,-56.8392 80.5921,-53.2367 86.1345,-62.2663 90.5557,-56.8392"/>
# </g>
# <!-- 5 -->
# <g id="node6" class="node"><title>5</title>
# <polygon fill=

# %% [markdown]
# This looks simple and elegent

# %% [markdown]
# ### (i) Produce a pruned tree corresponding to the optimal tree size obtained using cross-validation. If cross-validation does not lead to selection of a pruned tree, then create a pruned tree with five terminal nodes.

# %%
# pruned tree with 5 terminal nodes
pruned_tree = DecisionTreeClassifier(max_leaf_nodes=5)
pruned_tree.fit(X_train,y_train)
dot_data = tree.export_graphviz(pruned_tree, out_file=None, 
                                feature_names=X_train.columns,  
                                filled=True)
# Draw graph
graph = graphviz.Source(dot_data) 
display(HTML(graph._repr_svg_()))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: Tree Pages: 1 -->
# <svg width="518pt" height="373pt"
#  viewBox="0.00 0.00 518.00 373.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 369)">
# <title>Tree</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-369 514,-369 514,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node"><title>0</title>
# <polygon fill="#f5ceb2" stroke="black" points="310.5,-365 188.5,-365 188.5,-297 310.5,-297 310.5,-365"/>
# <text text-anchor="middle" x="249.5" y="-349.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.454</text>
# <text text-anchor="middle" x="249.5" y="-334.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.471</text>
# <text text-anchor="middle" x="249.5" y="-319.8" font-family="Times New Roman,serif" font-size="14.00">samples = 800</text>
# <text text-anchor="middle" x="249.5" y="-304.8" font-family="Times New Roman,serif" font-size="14.00">value = [496, 304]</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node"><title>1</title>
# <polygon fill="#75bbed" stroke="black" points="240.5,-261 118.5,-261 118.5,-193 240.5,-193 240.5,-261"/>
# <text text-anchor="middle" x="179.5" y="-245.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.276</text>
# <text text-anchor="middle" x="179.5" y="-230.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.356</text>
# <text text-anchor="middle" x="179.5" y="-215.8" font-family="Times New Roman,serif" font-size="14.00">samples = 289</text>
# <text text-anchor="middle" x="179.5" y="-200.8" font-family="Times New Roman,serif" font-size="14.00">value = [67, 222]</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge"><title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M226.773,-296.884C220.843,-288.243 214.376,-278.819 208.181,-269.793"/>
# <polygon fill="black" stroke="black" points="210.897,-267.564 202.353,-261.299 205.125,-271.525 210.897,-267.564"/>
# <text text-anchor="middle" x="197.78" y="-282.178" font-family="Times New Roman,serif" font-size="14.00">True</text>
# </g>
# <!-- 2 -->
# <g id="node5" class="node"><title>2</title>
# <polygon fill="#ea995f" stroke="black" points="380.5,-261 258.5,-261 258.5,-193 380.5,-193 380.5,-261"/>
# <text text-anchor="middle" x="319.5" y="-245.8" font-family="Times New Roman,serif" font-size="14.00">LoyalCH &lt;= 0.754</text>
# <text text-anchor="middle" x="319.5" y="-230.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.269</text>
# <text text-anchor="middle" x="319.5" y="-215.8" font-family="Times New Roman,serif" font-size="14.00">samples = 511</text>
# <text text-anchor="middle" x="319.5" y="-200.8" font-family="Times New Roman,serif" font-size="14.00">value = [429, 82]</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g id="edge4" class="edge"><title>0&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M272.227,-296.884C278.157,-288.243 284.624,-278.819 290.819,-269.793"/>
# <polygon fill="black" stroke="black" points="293.875,-271.525 296.647,-261.299 288.103,-267.564 293.875,-271.525"/>
# <text text-anchor="middle" x="301.22" y="-282.178" font-family="Times New Roman,serif" font-size="14.00">False</text>
# </g>
# <!-- 7 -->
# <g id="node3" class="node"><title>7</title>
# <polygon fill="#52a9e8" stroke="black" points="111,-149.5 0,-149.5 0,-96.5 111,-96.5 111,-149.5"/>
# <text text-anchor="middle" x="55.5" y="-134.3" font-family="Times New Roman,serif" font-size="14.00">gini = 0.201</text>
# <text text-anchor="middle" x="55.5" y="-119.3" font-family="Times New Roman,serif" font-size="14.00">samples = 168</text>
# <text text-anchor="middle" x="55.5" y="-104.3" font-family="Times New Roman,serif" font-size="14.00">value = [19, 149]</text>
# </g>
# <!-- 1&#45;&gt;7 -->
# <g id="edge2" class="edge"><title>1&#45;&gt;7</title>
# <path fill="none" stroke="black" d="M139.241,-192.884C124.801,-181.006 108.56,-167.646 94.2512,-155.876"/>
# <polygon fill="black" stroke="black" points="96.4706,-153.17 86.5242,-149.52 92.0237,-158.576 96.4706,-153.17"/>
# </g>
# <!-- 8 -->
# <g id="node4" class="node"><title>8</title>
# <polygon fill="#bbddf6" stroke="black" points="233.5,-149.5 129.5,-149.5 129.5,-96.5 233.5,-96.5 233.5,-149.5"/>
# <text text-anchor="middle" x="181.5" y="-134.3" font-family="Times New Roman,serif" font-size="14.00">gini = 0.479</text>
# <text text-anchor="middle" x="181.5" y="-119.3" font-family="Times New Roman,serif" font-size="14.00">samples = 121</text>
# <text text-anchor="middle" x="181.5" y="-104.3" font-family="Times New Roman,serif" font-size="14.00">value = [48, 73]</text>
# </g>
# <!-- 1&#45;&gt;8 -->
# <g id="edge3" class="edge"><title>1&#45;&gt;8</title>
# <path fill="none" stroke="black" d="M180.149,-192.884C180.359,-182.216 180.591,-170.352 180.804,-159.519"/>
# <polygon fill="black" stroke="black" points="184.303,-159.587 181,-149.52 177.304,-159.449 184.303,-159.587"/>
# </g>
# <!-- 3 -->
# <g id="node6" class="node"><title>3</title>
# <polygon fill="#f0b48a" stroke="black" points="380.5,-157 254.5,-157 254.5,-89 380.5,-89 380.5,-157"/>
# <text text-anchor="middle" x="317.5" y="-141.8" font-family="Times New Roman,serif" font-size="14.00">PriceDiff &lt;= &#45;0.165</text>
# <text text-anchor="middle" x="317.5" y="-126.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.411</text>
# <text text-anchor="middle" x="317.5" y="-111.8" font-family="Times New Roman,serif" font-size="14.00">samples = 249</text>
# <text text-anchor="middle" x="317.5" y="-96.8" font-family="Times New Roman,serif" font-size="14.00">value = [177, 72]</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge5" class="edge"><title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M318.851,-192.884C318.692,-184.778 318.519,-175.982 318.352,-167.472"/>
# <polygon fill="black" stroke="black" points="321.848,-167.229 318.153,-157.299 314.85,-167.366 321.848,-167.229"/>
# </g>
# <!-- 4 -->
# <g id="node9" class="node"><title>4</title>
# <polygon fill="#e68641" stroke="black" points="510,-149.5 399,-149.5 399,-96.5 510,-96.5 510,-149.5"/>
# <text text-anchor="middle" x="454.5" y="-134.3" font-family="Times New Roman,serif" font-size="14.00">gini = 0.073</text>
# <text text-anchor="middle" x="454.5" y="-119.3" font-family="Times New Roman,serif" font-size="14.00">samples = 262</text>
# <text text-anchor="middle" x="454.5" y="-104.3" font-family="Times New Roman,serif" font-size="14.00">value = [252, 10]</text>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g id="edge8" class="edge"><title>2&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M363.331,-192.884C379.197,-180.896 397.06,-167.399 412.743,-155.549"/>
# <polygon fill="black" stroke="black" points="414.855,-158.341 420.724,-149.52 410.635,-152.756 414.855,-158.341"/>
# </g>
# <!-- 5 -->
# <g id="node7" class="node"><title>5</title>
# <polygon fill="#87c4ef" stroke="black" points="306.5,-53 202.5,-53 202.5,-0 306.5,-0 306.5,-53"/>
# <text text-anchor="middle" x="254.5" y="-37.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.405</text>
# <text text-anchor="middle" x="254.5" y="-22.8" font-family="Times New Roman,serif" font-size="14.00">samples = 39</text>
# <text text-anchor="middle" x="254.5" y="-7.8" font-family="Times New Roman,serif" font-size="14.00">value = [11, 28]</text>
# </g>
# <!-- 3&#45;&gt;5 -->
# <g id="edge6" class="edge"><title>3&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M295.466,-88.9485C289.611,-80.1664 283.275,-70.6629 277.377,-61.815"/>
# <polygon fill="black" stroke="black" points="280.117,-59.6158 271.658,-53.2367 274.293,-63.4987 280.117,-59.6158"/>
# </g>
# <!-- 6 -->
# <g id="node8" class="node"><title>6</title>
# <polygon fill="#eca26d" stroke="black" points="436,-53 325,-53 325,-0 436,-0 436,-53"/>
# <text text-anchor="middle" x="380.5" y="-37.8" font-family="Times New Roman,serif" font-size="14.00">gini = 0.331</text>
# <text text

# %%
unpruned_tree = DecisionTreeClassifier()
unpruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ### (j) Compare the training error rates between the pruned and unpruned trees. Which is higher?

# %%
print('Training error for pruned ',np.round(1 - (pruned_tree.score(X_train,y_train)),4))
print('Training error for unpruned ',np.round(1 - (unpruned_tree.score(X_train,y_train)),4))
# Out:
# Training error for pruned  0.165
# Training error for unpruned  0.01

# %% [markdown]
# ### (k) Compare the test error rates between the pruned and unpruned trees. Which is higher?

# %%
print('Test error for pruned ',np.round(1 - (pruned_tree.score(X_test,y_test)),4))
print('Test error for unpruned ',np.round(1 - (unpruned_tree.score(X_test,y_test)),4))
# Out:
# Test error for pruned  0.1815
# Test error for unpruned  0.2333

# %% [markdown]
# From the above results, it can be seen that the unpruned tree is highly overfitting

# %% [markdown]
# ## 10. We now use boosting to predict Salary in the Hitters data set.

# %%
data = pd.read_csv(r'E:\programming\dataset\Into_to_statstical_learning\Hitters.csv')
data = data.iloc[:,1:] #removing the first col, which contains names
print(data.shape)
data.head()
# Out:
# (322, 20)
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
#lets check for cat columns
cat = [col for col in data.columns if data[col].dtype == 'O']
for col in cat:
    print(col)
    print(data[col].value_counts())
    print()
# Out:
# League
# A    175
# N    147
# Name: League, dtype: int64
#
# Division
# W    165
# E    157
# Name: Division, dtype: int64
#
# NewLeague
# A    176
# N    146
# Name: NewLeague, dtype: int64

# %%
# encoding the cat cols 
data['League'] = data['League'].map({'A':0,'N':1})
data['Division'] = data['Division'].map({'W':0,'E':1})
data['NewLeague'] =  data['NewLeague'].map({'A':0,'N':1})

# %% [markdown]
# Now we have all the cols in numerics

# %% [markdown]
# ### (a) Remove the observations for whom the salary information is unknown, and then log-transform the salaries

# %%
# removing the null values (only the salary col has null values)
data.dropna(inplace = True)

#log_transforming the salaries 
data['Salary_log'] = np.log(data['Salary'])

# %%
# how does the data looks like now!!
print(data.shape)
data.head()
# Out:
# (263, 21)
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  ...  \
# 1    315    81      7    24   38     39     14    3449    835      69  ...
# 2    479   130     18    66   72     76      3    1624    457      63  ...
# 3    496   141     20    65   78     37     11    5628   1575     225  ...
# 4    321    87     10    39   42     30      2     396    101      12  ...
# 5    594   169      4    74   51     35     11    4408   1133      19  ...
#
#    CRBI  CWalks  League  Division  PutOuts  Assists  Errors  Salary  \
# 1   414     375       1         0      632       43      10   475.0
# 2   266     263       0         0      880       82      14   480.0
# 3   838     354       1         1      200       11       3   500.0
# 4    46      33       1         1      805       40       4    91.5
# 5   336     194       0         0      282      421      25   750.0
#
#    NewLeague  Salary_log
# 1          1    6.163315
# 2          0    6.173786
# 3          1    6.214608
# 4          1    4.516339
# 5          0    6.620073
#
# [5 rows x 21 columns]

# %% [markdown]
# It must be tiring to hear this now, but i request you to go throught the whole of the dataset. Like what it describes, what are each of the columns, and how this could be useful. (This is what matters in the end)

# %% [markdown]
# ### (b) Create a training set consisting of the first 200 observations, and a test set consisting of the remaining observations.

# %%
X_train,X_test,y_train,y_test = train_test_split(data.drop(['Salary','Salary_log'],axis = 1),data['Salary_log'],
                                                    test_size = 0.239,random_state = 1)
#test_size = 63 / 253
print(X_train.shape,X_test.shape)
# Out:
# (200, 19) (63, 19)

# %% [markdown]
# ### (c) Perform boosting on the training set with 1,000 trees for a range of values of the shrinkage parameter λ. Produce a plot with different shrinkage values on the x-axis and the corresponding training set MSE on the y-axis.

# %%
# we are going to use XGboost here, we saw in the labs that XGboost performs better than Adaboost
scores_dict_train = {}
scores_dict_test = {}
gamma_values = np.linspace(0,1,50)
for gamma in (gamma_values):
    xgb = XGBRegressor(n_estimators=1000,gamma=gamma)
    xgb.fit(X_train,y_train)
    scores_dict_train[gamma] = mean_squared_error(y_train,xgb.predict(X_train))
    scores_dict_test[gamma] = mean_squared_error(y_test,xgb.predict(X_test))
# Out:
# [14:34:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:34:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
plt.figure(figsize = (10,6))
plt.plot(list(scores_dict_train.keys()),list(scores_dict_train.values()))
plt.plot(min(scores_dict_train, key=scores_dict_train.get),min(list(scores_dict_train.values())),marker = 'o',markersize = 8,c='r',label = 'min_error')
plt.legend()
plt.xlabel('Value of Shrinkage parameter')
plt.ylabel('Training Error')
# Out:
# Text(0, 0.5, 'Training Error')

# %% [markdown]
# ### (d) Produce a plot with different shrinkage values on the x-axis and the corresponding test set MSE on the y-axis.

# %%
plt.figure(figsize = (10,6)) 
plt.plot(list(scores_dict_test.keys()),list(scores_dict_test.values()))
plt.plot(min(scores_dict_test, key=scores_dict_test.get),min(list(scores_dict_test.values())),marker = 'o',markersize = 8,c='r',label = 'min_error')
plt.legend()
plt.xlabel('Value of Shrinkage parameter')
plt.ylabel('Test Error')
# Out:
# Text(0, 0.5, 'Test Error')

# %% [markdown]
# The value of test mse is min when value of shrinkage paramter is 0.326

# %% [markdown]
# ### (e) Compare the test MSE of boosting to the test MSE that results from applying two of the regression approaches seen in Chapters 3 and 6.

# %% [markdown]
# ### Ridge

# %%
scores_dict_ridge = {}
list_alpha = 10**np.linspace(-2,5,100)
for alpha in list_alpha:
    model = Ridge(alpha=alpha) 
    model.fit(X_train,y_train)
    scores_dict_ridge[alpha] = mean_squared_error(y_test,model.predict(X_test))

# %% [markdown]
# ### Lasso

# %%
scores_dict_lasso = {}
list_alpha = 10**np.linspace(-2,5,100)
for alpha in list_alpha:
    model = Lasso(alpha=alpha) 
    model.fit(X_train,y_train)
    scores_dict_lasso[alpha] = mean_squared_error(y_test,model.predict(X_test))

# %%
plt.figure(figsize = (10,6)) 
plt.plot(list(scores_dict_ridge.keys()),list(scores_dict_ridge.values()),label = 'Ridge')
plt.plot(list(scores_dict_lasso.keys()),list(scores_dict_lasso.values()),label = 'Lasso')
plt.legend()
plt.xlabel('Value of Shrinkage parameter')
plt.ylabel('Test Error')
plt.xscale('log')

# %%
# lets find out the best test mse value for both the cases 
print('Best test MSE for RIdge is ',min(scores_dict_ridge.values()))
print('Best test MSE for LASSO is ',min(scores_dict_lasso.values()))
# Out:
# Best test MSE for RIdge is  0.4526550397946496
# Best test MSE for LASSO is  0.46212503533185395

# %% [markdown]
# HMMMM, very close to each other

# %%
# what was the best test MSE for boosting 
print('Best TEST MSE for Boosting is ',min(scores_dict_test.values()))
# Out:
# Best TEST MSE for Boosting is  0.22566341064749135

# %% [markdown]
# We can see that boosting outperforms the other methods..(BY A MILE)

# %% [markdown]
# ### (f) Which variables appear to be the most important predictors in the boosted model?

# %%
best_boosting_model = XGBRegressor(n_estimators=1000,gamma=0.326)
best_boosting_model.fit(X_train,y_train)
# Out:
# [15:05:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.326,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
# feature importance
pd.Series(best_boosting_model.feature_importances_,index = X_train.columns).sort_values(ascending=False).plot.bar(figsize = (10,6))
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# The three features CatBat, Chits, Cruns, are the most important features to determine Salary

# %% [markdown]
# ### (g) Now apply bagging to the training set. What is the test set MSE for this approach?

# %%
base_reg = DecisionTreeRegressor()
bagging = BaggingRegressor(base_reg)
bagging.fit(X_train,y_train)
print('Training MSE ',mean_squared_error(y_train,bagging.predict(X_train)))
print('Test MSE ',mean_squared_error(y_test,bagging.predict(X_test)))
# Out:
# Training MSE  0.03447935767697594
# Test MSE  0.2834516144699629

# %% [markdown]
# It gives Test MSE of 0.28, which is close but not better than the MSE we got from Boosting, which was 0.22

# %% [markdown]
# ### 11. This question uses the Caravan data set.

# %%
data = pd.read_csv('E:\programming\dataset\Into_to_statstical_learning\Caravan.csv')
print(data.shape)
data = data.iloc[:,1:] #removing the first col
data.head()
# Out:
# (5822, 87)
#    MOSTYPE  MAANTHUI  MGEMOMV  MGEMLEEF  MOSHOOFD  MGODRK  MGODPR  MGODOV  \
# 0       33         1        3         2         8       0       5       1
# 1       37         1        2         2         8       1       4       1
# 2       37         1        2         2         8       0       4       2
# 3        9         1        3         3         3       2       3       2
# 4       40         1        4         2        10       1       4       1
#
#    MGODGE  MRELGE  ...  APERSONG  AGEZONG  AWAOREG  ABRAND  AZEILPL  APLEZIER  \
# 0       3       7  ...         0        0        0       1        0         0
# 1       4       6  ...         0        0        0       1        0         0
# 2       4       3  ...         0        0        0       1        0         0
# 3       4       5  ...         0        0        0       1        0         0
# 4       4       7  ...         0        0        0       1        0         0
#
#    AFIETS  AINBOED  ABYSTAND  Purchase
# 0       0        0         0        No
# 1       0        0         0        No
# 2       0        0         0        No
# 3       0        0         0        No
# 4       0        0         0        No
#
# [5 rows x 86 columns]

# %%
# lets check for any cat values
[col for col in data.columns if data[col].dtype == 'O']
# Out:
# ['Purchase']

# %% [markdown]
# Only the response value is categorical, which is Yes or No, lets encode it then

# %%
data['Purchase'] = data['Purchase'].map({'Yes':1,'No':0})

# %% [markdown]
# ### (a) Create a training set consisting of the first 1,000 observations, and a test set consisting of the remaining observations.

# %%
train_data = data.iloc[:1000,:]
X_train = train_data.drop('Purchase',axis = 1)
y_train = train_data['Purchase']

test_data = data.iloc[1000:,:]
X_test = test_data.drop('Purchase',axis = 1)
y_test = test_data['Purchase']

print(X_train.shape,X_test.shape)
# Out:
# (1000, 85) (4822, 85)

# %% [markdown]
# ### (b) Fit a boosting model to the training set with Purchase as the response and the other variables as predictors. Use 1,000 trees, and a shrinkage value of 0.01. Which predictors appear to be the most important?

# %%
model = XGBClassifier(n_estimators=1000,gamma=0.01)
model.fit(X_train,y_train)
print('Training score ',model.score(X_train,y_train))
# Out:
# Training score  0.996

# %%
# feature importance
pd.Series(model.feature_importances_,index = X_train.columns).sort_values(ascending=False)[:10].plot.bar(figsize = (10,6))
plt.title('Top 10 important features')
# Out:
# Text(0.5, 1.0, 'Top 10 important features')

# %% [markdown]
# Above are the 10 most important features

# %% [markdown]
# ### (c) Use the boosting model to predict the response on the test data. Predict that a person will make a purchase if the estimated probability of purchase is greater than 20 %. Form a confusion matrix. What fraction of the people predicted to make a purchase do in fact make one? How does this compare with the results obtained from applying KNN or logistic regression to this data set?

# %%
print('Test Accuracy is ', model.score(X_test,y_test))
# Out:
# Test Accuracy is  0.9222314392368312

# %% [markdown]
# By default, the model will consider that a person will make a purchase if the estimated probabilirt of purchase is graeter than 20%.

# %%
pred_probs = model.predict_proba(X_test)[:,0]
pred_probs
# Out:
# array([0.9999833 , 0.99632144, 0.9994091 , ..., 0.9902176 , 0.58748806,
#        0.9891333 ], dtype=float32)

# %%
# if predicted prob > 0.2, then class 1, otherwise 0
pred_class = np.where(pred_probs>0.2,1,0)

# %%
print('Accuracy is ',accuracy_score(y_test,pred_class))
# Out:
# Accuracy is  0.06698465367067606

# %%
#confusion matrix 
cm = confusion_matrix(y_test,pred_class)
pd.DataFrame(cm,columns = ['Pred_0','Pred_1'],index = ['True_0','True_1'])
# Out:
#         Pred_0  Pred_1
# True_0      44    4489
# True_1      10     279

# %% [markdown]
# So, only 0.05 fraction of the population predicted by the model, will actually make a purchase..I think the model is being too optimistic here.

# %% [markdown]
# ### KNN

# %%
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train,y_train)
pred_probas = knn.predict_proba(X_test)

pred_classes = np.where(pred_probas>0.2,1,0)[:,0]
print('Score for KNN ',accuracy_score(y_test,pred_classes))
# Out:
# Score for KNN  0.05993363749481543

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)

pred_probas = lr.predict_proba(X_test)

pred_classes = np.where(pred_probas>0.2,1,0)[:,0]
print('Score for Logistic Regression is ',accuracy_score(y_test,pred_classes))
# Out:
# Score for Logistic Regression is  0.06242223143923683

# %% [markdown]
# ### Although none of the model is looking good, boosting performs the best amonst them
